# %% [markdown]
# <a href="https://colab.research.google.com/github/nsriniva/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/module3-dimensionality-reduction/LS_DS_133_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
import matplotlib.pyplot as plt


def plot_graph(xy, axes, color='green'):

  orig = xy[0]
  for v in xy[1:]:
    vt = np.array(v) - np.array(orig)
    plt.arrow(*orig, *vt, head_width=0, head_length=0,color = color)
    orig = v


funcv = [(2,5), (3,6), (4,7),(5,5)]

nfuncv = [(0,0), (1,1),(2,3), (1,4) ]

fig,axes = plt.subplots()

fig.set_size_inches(5,5)

axes.set_xlim(-1, 7)
axes.set_ylim(-1,7)

#Plotting graph funcv(in green) that passes the vertical line test
plot_graph(funcv, axes)

#Plotting graph nfuncv(in red) that fails the vertical line test
plot_graph(nfuncv, axes, 'red')

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# Graphs that don't pass the vertical line test are not considered functions because they violate the requirement that every input(x) has to be mapped to exactly one output(y).

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}
#
# Relation 2 is the only function because it is the only relation that satisfies the requirement that every input(x) has to be mapped to exactly one output(y).
#
# Relationship 1 has 2 mapping for 1(2,3)
# Relationship 3 has 2 mappings for 9(4,6)
# Relationship 4 has 2 mappings for 6(2,4)
# Relationship 5 has 3 mappings for 2(6,7,4)

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}
#
# For the function $m$, the dimensionality of both the domain and codomain is 3.
#
# For the function $n$, the dimensionalities of the domain and codomain are 4 and 2, respectively.

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %% [markdown]
# Yes, it's possible to create a function that maps from a lower dimensional to a higher dimensional space e.g. $f(x) = (x,x)$

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
p = lambda x1,x2: [x1+3*x2, 2*x2-x1]

q = lambda x1,x2,x3: [4*x1+x2+2*x3, 2*x2-x1+3*x3, 5*x1-2*x3+x2]

P = np.array([p(1,0), p(0,1)])

Q = np.array([q(1, 0, 0), q(0, 1, 0), q(0, 0, 1)])

vp = np.array([5,6])

vq = np.array([1,2,3])

p1 = p(*vp)

display(p1)

p2 = np.matmul(P.T, vp)

display(p2)

q1 = q(*vq)

display(q1)

q2 = np.matmul(Q.T, vq)

display(q2)
# Out:
# [23, 7]
# array([23,  7])
# [12, 12, 1]
# array([12, 12,  1])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.
# The eigenvectors($X_i$) of a transformation $A$ are the set of vectors which are only scaled(by a scalar $\lambda_i$, called the eigenvalue) as a result of A being applied to them i.e.
#
# $AX_i$ = $\lambda_i$$X$

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?
# One of the biggest challenges of working with high dimensional spaces is not having sufficient observations to be able to recognize useful patterns e.g. in the 2 dimensional space $\mathbb{R}^2$, you can't identify a line unless you have at least 2 observations and in the 3 dimensional space $\mathbb{R}^3$, you can't identify a plane unless you have at least 3 observations.
#
# The other problem is with not fitting the data correctly because the fewer the observations, the greater the risk of overfitting e.g. in the $\mathbb{R}^2$ case, having just 2 observations will give us a line that fits those 2 observations exactly but might not fit any new data; similarly, in the the $\mathbb{R}^3$ space, having just 3 observations will give us a plane that fits those 3 observations exactly but might not fit any new data.

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?
# The rule of thumb is that the number of observations should be at least 5 times the number of parameters.

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 0  '100003130103'    82    '3'  ...     '2 30% to 50%'       '-5'       '-5'
# 1  '100006110249'    50    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 2  '100006370140'    53    '5'  ...    '3 50% or More'       '-5'       '-5'
# 3  '100006520140'    67    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 4  '100007130148'    26    '1'  ...  '1 Less than 30%'       '-5'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.head()
# Out:
# (64535, 99)
#    CONTROL  AGE1  METRO3  REGION  ...  FMTASSISTED  FMTBURDEN  FMTREGION  FMTSTATUS
# 0        0    82       2       0  ...            0          2          0          0
# 1        1    50       4       2  ...            0          1          0          0
# 2        2    53       4       2  ...            0          3          0          0
# 3        3    67       4       2  ...            0          1          0          0
# 4        4    26       0       2  ...            1          1          0          0
#
# [5 rows x 99 columns]

# %%
# Now we only ahve numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
### Your Code Here
# national_processed does not appear to have been
# "one-hot-encoded" - the number of cols is still
# 99 but all the columns have been converted into
# numeric types.
# I (tried to) read the data definition doc 
# https://www.huduser.gov/portal/datasets/hads/HADS_doc.pdf
# but none of the attributes stick out as being a dependent
# attribute to be excluded, so leaving all 99 columns
# in.

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()

# Standardize the data
Z = scaler.fit_transform(national_processed)


# Create PCA instance
# We want the first 2 principal components

pca = PCA()

# New features data 
# Fit and transform in one go.

new_features = pca.fit_transform(Z)

partial_variance = 0
idx=0
var_map = {}
while partial_variance < 0.8:
  partial_variance += pca.explained_variance_ratio_[idx]
  var_map[idx] = partial_variance
  idx += 1

print(idx, partial_variance,'\n')

display(var_map)

print('\n')

# Display the eigen values in descending order for 
# the eigen values that constitute 80% of the total
display(pca.explained_variance_[:idx])

print('\n')

#Display the eigen values as a percentage of the total eigen values
#for the attributes encompassing 80% of the variance.
display(pca.explained_variance_ratio_[:idx])

print('\n')

new_df = pd.DataFrame(new_features, columns=[f'PC{i+1}' for i in range(99)])

display(new_df.head(5))
# Out:
# 8 0.802052522303302
# {0: 0.34050541641292265,
#  1: 0.48492705197480007,
#  2: 0.587803214725338,
#  3: 0.6602572255418198,
#  4: 0.7119230404570986,
#  5: 0.7519899519632878,
#  6: 0.7798485849504105,
#  7: 0.802052522303302}
# array([33.37004789, 14.1535396 , 10.08202018,  7.10060309,  5.06332832,
#         3.92661817,  2.73018834,  2.17601958])
# array([0.34050542, 0.14442164, 0.10287616, 0.07245401, 0.05166581,
#        0.04006691, 0.02785863, 0.02220394])
#         PC1       PC2       PC3  ...          PC97          PC98          PC99
# 0 -2.576570 -1.376127 -1.253835  ...  6.081237e-15 -5.551242e-16 -7.942743e-16
# 1  2.040643 -0.988061 -2.237999  ... -7.866356e-15 -6.322116e-16 -2.619343e-16
# 2  1.215270  0.370168 -3.248606  ...  3.318875e-15  8.989284e-16 -3.788372e-17
# 3  2.821837  1.723711 -4.375157  ... -1.618005e-15 -2.137277e-16 -7.535854e-16
# 4 -1.570106 -0.878362 -3.307062  ...  5.388211e-15 -7.548762e-16 -5.272142e-17
#
# [5 rows x 99 columns]

# %%
plt.scatter(new_df['PC1'], new_df['PC2'])
plt.title('PC1 against PC2')
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.show()

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
